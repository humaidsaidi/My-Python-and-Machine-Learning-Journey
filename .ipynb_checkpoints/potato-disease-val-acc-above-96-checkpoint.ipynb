# %% [markdown]
# # Introduction

# %%
# Setup
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 get_ipython().system('pip install cv2')
#       3 import os
# ----> 4 import cv2
#       5 import numpy as np
#       6 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Avoid OMM Error
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2023-01-22 16:06:33.877425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-22 16:06:33.990789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-22 16:06:33.991890: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
# check the GPU
physical_devices
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# define the images directory
data_dir = "/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256"
print(os.listdir(data_dir))
# Out:
# ['Validation', 'Training', 'Testing']

# %%
# let`s make EDA for the dataset
data_splits = os.listdir(data_dir)
for data_kind in data_splits:
    classes = os.listdir(os.path.join(data_dir,data_kind))
    print(f'*We Process the {data_kind}')
    for class_ in classes:
        path = os.path.join(os.path.join(data_dir,data_kind),class_)
        print(f'  we have a {len(os.listdir(path))} images from class {class_}')
    print('')
# Out:
# *We Process the Validation
#   we have a 151 images from class Late_Blight
#   we have a 163 images from class Early_Blight
#   we have a 102 images from class Healthy
#
# *We Process the Training
#   we have a 1132 images from class Late_Blight
#   we have a 1303 images from class Early_Blight
#   we have a 816 images from class Healthy
#
# *We Process the Testing
#   we have a 141 images from class Late_Blight
#   we have a 162 images from class Early_Blight
#   we have a 102 images from class Healthy

# %%
# Filter out Corrupted images

num_skipped = 0
data_splits = os.listdir(data_dir)

for data_kind in data_splits:
    data_kind_path = os.path.join(data_dir,data_kind)
    print(f'*We Process the {data_kind}')
    
    classes = os.listdir(data_kind_path)
    for class_ in classes:
        folder_path = os.path.join(data_kind_path,class_)
        for fname in os.listdir(folder_path):
            fpath = os.path.join(folder_path,fname)

            try:
                fobj = open(fpath,"rb")
                is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
            finally:
                fobj.close()

            if not is_jfif:
                num_skipped += 1
                os.remove(fpath)
    print(f"  Deleted {num_skipped} Images for {data_kind}\n")
# Out:
# *We Process the Validation
#   Deleted 0 Images for Validation
#
# *We Process the Training
#   Deleted 0 Images for Training
#
# *We Process the Testing
#   Deleted 0 Images for Testing

# %% [markdown]
# # Genrate a Dataset and Visualize

# %%
# load data with tf.utils.image_dataset_from_directory
IMAGE_SIZE = (256,256)
BATCH_SIZE = 16
SEED = 42

# make train-testing-validation datasets
def load_data(data_dir):
    data = []
    for class_d in os.listdir(data_dir):
        data.append(
            tf.keras.utils.image_dataset_from_directory(
            os.path.join(data_dir,class_d),
            image_size = IMAGE_SIZE,
            batch_size = BATCH_SIZE,
            seed = SEED)
                   )
    return data
# apllying the Load dataset
test_ds, train_ds, val_ds = load_data(data_dir)
# Out:
# Found 416 files belonging to 3 classes.
# 2023-01-22 16:06:43.876355: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-22 16:06:43.876725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-22 16:06:43.877574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-22 16:06:43.878200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-22 16:06:46.150472: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-22 16:06:46.151303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-22 16:06:46.151985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-22 16:06:46.152585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 3251 files belonging to 3 classes.
# Found 405 files belonging to 3 classes.

# %%
# plot Visualize 
plt.figure(figsize=(10,10))
for image, label in test_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(train_ds.class_names[label[i]])
        plt.axis("off");
# Out:
# 2023-01-22 16:06:46.800862: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %% [markdown]
# ## Standardize the data

# %%
# standardize values to be in the [0,1] range
normalization_layer = tf.keras.layers.Rescaling(1./255)

# using thr Dataset.map to apply this layer
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))

# check pixels after normalization
images_batch, label_batch = next(iter(normalized_ds))
random_image = images_batch[4]
print(f' min value = {np.min(random_image)} , max value =  {np.max(random_image)}')
# Out:
#  min value = 0.0 , max value =  1.0

# %% [markdown]
# # Configure the dataset for performance

# %%
# make sure to use buffered prefetching , yield the data without having I/O become bloking
def Configure(dataset):
    dataset = dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset

# apply the function
train_ds = Configure(train_ds)
val_ds = Configure(val_ds)

# %% [markdown]
# # Build a Model

# %%
# build a small version of the `Xception Network`

NUM_CLASSES = 3
INPUT_SHAPE = IMAGE_SIZE +(3,)
model = tf.keras.Sequential([
    
    # rescaling and Data augmentation block
    tf.keras.layers.RandomFlip("horizontal_and_vertical", input_shape=INPUT_SHAPE),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.Rescaling(1.0/255),
    
    # Conv2D Block
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    # Flatten Block
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    
],name = "Mido")


# plot the model
keras.utils.plot_model(model, show_shapes=True)

# %%
# Compile the Model  
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy'])

# %%
# Define Callback
class CustomCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if (logs.get('val_accuracy')>=0.98):   
            keys = list(logs.keys())
            print("End epoch {} of training; got log keys: {}".format(epoch, keys))
            self.model.stop_training = True
            
# define object from CustomCallback Class
callbacks = CustomCallback()

# %%
# training the model
EPOCHS = 50
history = model.fit(
                    train_ds,
                    validation_data=val_ds,
                    epochs =EPOCHS,
                    callbacks=[callbacks])
# Out:
# Epoch 1/50
# 2023-01-22 16:06:51.578384: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 204/204 [==============================] - 15s 32ms/step - loss: 1.0492 - accuracy: 0.4392 - val_loss: 1.0034 - val_accuracy: 0.5827
# Epoch 2/50
# 204/204 [==============================] - 4s 22ms/step - loss: 0.7580 - accuracy: 0.6776 - val_loss: 0.5487 - val_accuracy: 0.7704
# Epoch 3/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.5062 - accuracy: 0.8068 - val_loss: 0.4359 - val_accuracy: 0.8296
# Epoch 4/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.4010 - accuracy: 0.8527 - val_loss: 0.3380 - val_accuracy: 0.8840
# Epoch 5/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.2699 - accuracy: 0.8982 - val_loss: 0.4627 - val_accuracy: 0.8568
# Epoch 6/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.2107 - accuracy: 0.9237 - val_loss: 0.3709 - val_accuracy: 0.9086
# Epoch 7/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.2150 - accuracy: 0.9216 - val_loss: 0.2621 - val_accuracy: 0.9136
# Epoch 8/50
# 204/204 [==============================] - 5s 22ms/step - loss: 0.1742 - accuracy: 0.9379 - val_loss: 0.1732 - val_accuracy: 0.9432
# Epoch 9/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1368 - accuracy: 0.9536 - val_loss: 0.2220 - val_accuracy: 0.9160
# Epoch 10/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1250 - accuracy: 0.9554 - val_loss: 0.1284 - val_accuracy: 0.9630
# Epoch 11/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1456 - accuracy: 0.9511 - val_loss: 0.1530 - val_accuracy: 0.9531
# Epoch 12/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1250 - accuracy: 0.9560 - val_loss: 0.2387 - val_accuracy: 0.9358
# Epoch 13/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1251 - accuracy: 0.9585 - val_loss: 0.1338 - val_accuracy: 0.9630
# Epoch 14/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1092 - accuracy: 0.9662 - val_loss: 0.1101 - val_accuracy: 0.9654
# Epoch 15/50
# 204/204 [==============================] - 4s 22ms/step - loss: 0.1111 - accuracy: 0.9625 - val_loss: 0.0986 - val_accuracy: 0.9630
# Epoch 16/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1109 - accuracy: 0.9659 - val_loss: 0.1830 - val_accuracy: 0.9457
# Epoch 17/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1132 - accuracy: 0.9619 - val_loss: 0.1186 - val_accuracy: 0.9654
# Epoch 18/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1038 - accuracy: 0.9683 - val_loss: 0.1780 - val_accuracy: 0.9580
# Epoch 19/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1032 - accuracy: 0.9640 - val_loss: 0.1365 - val_accuracy: 0.9630
# Epoch 20/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0917 - accuracy: 0.9708 - val_loss: 0.1203 - val_accuracy: 0.9605
# Epoch 21/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0875 - accuracy: 0.9711 - val_loss: 0.1415 - val_accuracy: 0.9605
# Epoch 22/50
# 204/204 [==============================] - 4s 22ms/step - loss: 0.0909 - accuracy: 0.9723 - val_loss: 0.1320 - val_accuracy: 0.9630
# Epoch 23/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0867 - accuracy: 0.9720 - val_loss: 0.1362 - val_accuracy: 0.9531
# Epoch 24/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0784 - accuracy: 0.9757 - val_loss: 0.1232 - val_accuracy: 0.9506
# Epoch 25/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0852 - accuracy: 0.9705 - val_loss: 0.1058 - val_accuracy: 0.9630
# Epoch 26/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0699 - accuracy: 0.9782 - val_loss: 0.0910 - val_accuracy: 0.9704
# Epoch 27/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0848 - accuracy: 0.9732 - val_loss: 0.0586 - val_accuracy: 0.9728
# Epoch 28/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0690 - accuracy: 0.9788 - val_loss: 0.1119 - val_accuracy: 0.9630
# Epoch 29/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0632 - accuracy: 0.9825 - val_loss: 0.2174 - val_accuracy: 0.9556
# Epoch 30/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0819 - accuracy: 0.9732 - val_loss: 0.1411 - val_accuracy: 0.9630
# Epoch 31/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0744 - accuracy: 0.9766 - val_loss: 0.0802 - val_accuracy: 0.9728
# Epoch 32/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0776 - accuracy: 0.9748 - val_loss: 0.0681 - val_accuracy: 0.9753
# Epoch 33/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0713 - accuracy: 0.9782 - val_loss: 0.1109 - val_accuracy: 0.9679
# Epoch 34/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0712 - accuracy: 0.9794 - val_loss: 0.1065 - val_accuracy: 0.9704
# Epoch 35/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0714 - accuracy: 0.9757 - val_loss: 0.0924 - val_accuracy: 0.9778
# Epoch 36/50
# 204/204 [==============================] - 4s 22ms/step - loss: 0.0626 - accuracy: 0.9797 - val_loss: 0.0774 - val_accuracy: 0.9704
# Epoch 37/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0556 - accuracy: 0.9800 - val_loss: 0.0495 - val_accuracy: 0.9901
# End epoch 36 of training; got log keys: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %% [markdown]
# # Model Evaluation

# %%
# list all data in history
print(history.history.keys())
print("")
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')

# summarize history for loss
plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evalute model
model.evaluate(test_ds)
# Out:
# 26/26 [==============================] - 1s 16ms/step - loss: 0.0524 - accuracy: 0.9784
# [0.05241440236568451, 0.9783653616905212]

# %%
# To Color The Output
from termcolor import colored

# %%
# ok everythink look nice, let`s check pic manually
for image_batch, label_batch in test_ds.take(1):
    idx = np.random.randint(0,15)
    print(f"The Real Image was: ",colored({test_ds.class_names[label[idx]]}, 'red'),"\n")
    plt.imshow(image_batch[idx].numpy().astype('uint8'))
    plt.title(test_ds.class_names[label[idx]])
    plt.axis("off");
    plt.show()
    
    print(f"\nThe Model Prediction was: \n")
    print(image_batch.shape)
    pred = model.predict(image_batch)
    pred_idx = np.argmax(pred[idx])
    confidence = str(round(100*(np.max(pred[idx])), 2)) + " %"
    print("")
    print("Class From Model Prediction is :",colored({test_ds.class_names[label[pred_idx]]}, 'green')," with confidence =",colored({confidence},'yellow'))
# Out:
# The Real Image was:  {'Early_Blight'}
# The Model Prediction was:
#
# (16, 256, 256, 3)
#
# Class From Model Prediction is : {'Early_Blight'}  with confidence = {'99.61 %'}

# %%
# saving the model
model.save('save_model')
# Out:
# 2023-01-22 16:09:54.628435: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %% [markdown]
# # Convert to ONNX

# %%
# # Convert to ONNX using the Python API
# !pip install tf2onnx onnxruntime
# import tf2onnx
# import onnxruntime as rt

# spec = (tf.TensorSpec((None, 256, 256, 3), tf.float32, name="input"),)
# output_path = model.name + ".onnx"

# model_proto, _ = tf2onnx.convert.from_keras(model, input_signature=spec, opset=13, output_path=output_path)
# output_names = [n.name for n in model_proto.graph.output]

# %%
# # Convert to ONNX using the command line

# !python3 -m tf2onnx.convert --opset 13 \
#     --saved-model {os.path.join("","save_model" )} \
#     --output  {os.path.join("save_model", model.name + ".onnx")}

# %%
path = os.path.join("/save_model", model.name + ".onnx")
print(path)
# Out:
# /save_model/Mido.onnx
